# %% [markdown]
# # Your First Knowledge Graph
#
# ## Overview
#
# This notebook walks you through creating your first knowledge graph from a simple document.
#
# ## Simple End-to-End Workflow
#
# The workflow: File → Parse → Extract → Graph
#
# ## Step 1: Ingest a File
#
# '''
# # from semantica.ingest import FileIngestor
# #
# # ingestor = FileIngestor()
# # documents = ingestor.ingest("path/to/your/file.pdf")
# '''
#
# ## Step 2: Parse the Document
#
# '''
# # from semantica.parse import DocumentParser
# #
# # parser = DocumentParser()
# # parsed_docs = parser.parse(documents)
# '''
#
# ## Step 3: Extract Entities
#
# '''
# # from semantica.semantic_extract import NERExtractor
# #
# # extractor = NERExtractor()
# # entities = extractor.extract(parsed_docs)
# '''
#
# ## Step 4: Build the Knowledge Graph
#
# '''
# # from semantica.kg import GraphBuilder
# #
# # builder = GraphBuilder()
# # knowledge_graph = builder.build(entities)
# #
# # # View the graph
# # print(f"Graph has {len(knowledge_graph.nodes)} nodes and {len(knowledge_graph.edges)} edges")
# '''
#
# ## See Results Immediately
#
# '''
# # You can visualize the graph or export it to see the results
# # from semantica.visualization import KGVisualizer
# #
# # visualizer = KGVisualizer()
# # visualizer.visualize(knowledge_graph)
# '''
