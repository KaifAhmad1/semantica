# %% [markdown]
# <a href="https://colab.research.google.com/github/KaifAhmad1/semantica/blob/main/cookbook/use_cases/finance/03_Earnings_Call_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hawksight-AI/semantica/blob/main/cookbook/use_cases/finance/03_Earnings_Call_Analysis.ipynb)
#
# # Earnings Call Analysis with Docling, Semantica & AWS Neptune
# MDA Space Ltd. — Q3 2025
#
# ## Data Sources
#
# This notebook analyzes two financial documents from **MDA Space Ltd.** for Q3 2025:
#
# 1. **Press Release** — Summary of financial results and management commentary
# 2. **Earnings Call Transcript** — Management presentation and analyst Q&A
#
# Together, these documents provide both quantitative results and qualitative context.
#
# ---
#
# ## Overview
#
# This notebook demonstrates an end-to-end semantic pipeline for transforming
# unstructured financial documents into structured, queryable knowledge.
#
# **Docling** is used for high-fidelity document parsing. **Semantica** performs
# semantic extraction, cleaning, validation, and knowledge graph construction.
# The final knowledge graph is stored in **AWS Neptune** and used for hybrid
# retrieval, agent memory, and grounded question answering.
#
# ---
#
# ## End-to-End Workflow
#
# **Workflow:**
# Dual PDF Input → Docling Parsing → Normalization & Chunking → Entity, Relation Extraction → Conflict Resolution & Deduplication → Knowledge Graph Construction → Amazon Neptune → GraphRAG → Agent Memory & Context → Strategic Q&A
#
# ---
#
# ## Pipeline Capabilities
#
# - High-fidelity PDF parsing (text, tables, structure)
# - Semantic extraction of entities, and relationships
# - Conflict detection and resolution with confidence awareness
# - Entity deduplication and canonicalization
# - Knowledge graph construction and validation
# - Persistent graph storage in **AWS Neptune** (IAM, OpenCypher)
# - Hybrid retrieval using **GraphRAG** (vector + graph)
# - Long-term agent memory and unified context management
# - Grounded LLM-based question answering
# - Structured export to JSON and RDF formats
#
# ---
#
# ## Outcome
#
# The output is a cleaned, deduplicated knowledge graph stored in **AWS Neptune**,
# along with supporting context for hybrid retrieval and question answering.
# This enables reliable financial analysis and downstream applications built
# on structured, traceable knowledge.

# %%
# !pip install git+https://github.com/Hawksight-AI/semantica.git@main
# !pip install -qU docling pdfplumber groq
# Out:
# Collecting git+https://github.com/Hawksight-AI/semantica.git@main
#   Cloning https://github.com/Hawksight-AI/semantica.git (to revision main) to /tmp/pip-req-build-et063dbg
#   Running command git clone --filter=blob:none --quiet https://github.com/Hawksight-AI/semantica.git /tmp/pip-req-build-et063dbg
#   Resolved https://github.com/Hawksight-AI/semantica.git to commit 064a0db7e6ded462bc6b10fa62228a7508fde468
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (2.0.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (1.6.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (0.5.9.post2)
# Requirement already satisfied: spacy>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (3.8.11)
# Requirement already satisfied: transformers>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (4.57.3)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (2.9.0+cu126)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (5.2.0)
# Collecting rdflib>=6.2.0 (from semantica==0.2.2)
#   Downloading rdflib-7.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (3.6.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (3.10.0)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (0.13.2)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (5.24.1)
# Collecting ipywidgets>=8.0.0 (from semantica==0.2.2)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (2.32.4)
# Requirement already satisfied: GitPython>=3.1.30 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (3.1.46)
# Requirement already satisfied: chardet>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (5.2.0)
# Requirement already satisfied: protobuf<7.0,>=5.29.1 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (5.29.5)
# Requirement already satisfied: grpcio>=1.71.2 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (1.76.0)
# Requirement already satisfied: beautifulsoup4>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (4.13.5)
# Requirement already satisfied: lxml>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (6.0.2)
# Collecting pypdf2>=2.10.0 (from semantica==0.2.2)
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting python-docx>=0.8.11 (from semantica==0.2.2)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: openpyxl>=3.0.10 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (3.1.5)
# Requirement already satisfied: pillow>=9.2.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (11.3.0)
# Requirement already satisfied: librosa>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (0.11.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (4.12.0.88)
# Collecting faiss-cpu>=1.7.0 (from semantica==0.2.2)
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Collecting fastembed>=0.2.0 (from semantica==0.2.2)
#   Downloading fastembed-0.7.4-py3-none-any.whl.metadata (10 kB)
# Collecting onnxruntime>=1.17.0 (from semantica==0.2.2)
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: tokenizers>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (0.22.2)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (2.12.3)
# Requirement already satisfied: click>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (8.3.1)
# Requirement already satisfied: rich>=12.5.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (13.9.4)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (4.67.1)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (6.0.3)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (0.10.2)
# Requirement already satisfied: python-dotenv>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from semantica==0.2.2) (1.2.1)
# Collecting loguru>=0.6.0 (from semantica==0.2.2)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting structlog>=22.1.0 (from semantica==0.2.2)
#   Downloading structlog-25.5.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.0->semantica==0.2.2) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.0->semantica==0.2.2) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu>=1.7.0->semantica==0.2.2) (25.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.20 in /usr/local/lib/python3.12/dist-packages (from fastembed>=0.2.0->semantica==0.2.2) (0.36.0)
# Requirement already satisfied: mmh3<6.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from fastembed>=0.2.0->semantica==0.2.2) (5.2.0)
# Collecting py-rust-stemmers<0.2.0,>=0.1.0 (from fastembed>=0.2.0->semantica==0.2.2)
#   Downloading py_rust_stemmers-0.1.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython>=3.1.30->semantica==0.2.2) (4.0.12)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.0->semantica==0.2.2)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.0->semantica==0.2.2) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.0->semantica==0.2.2) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=8.0.0->semantica==0.2.2)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.0->semantica==0.2.2) (3.0.16)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (1.16.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.9.0->semantica==0.2.2) (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->semantica==0.2.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->semantica==0.2.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->semantica==0.2.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->semantica==0.2.2) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->semantica==0.2.2) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->semantica==0.2.2) (2.9.0.post0)
# Collecting coloredlogs (from onnxruntime>=1.17.0->semantica==0.2.2)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->semantica==0.2.2) (25.12.19)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->semantica==0.2.2) (1.14.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.0.10->semantica==0.2.2) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->semantica==0.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->semantica==0.2.2) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->semantica==0.2.2) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->semantica==0.2.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->semantica==0.2.2) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->semantica==0.2.2) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->semantica==0.2.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->semantica==0.2.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->semantica==0.2.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->semantica==0.2.2) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.5.0->semantica==0.2.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.5.0->semantica==0.2.2) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->semantica==0.2.2) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (0.21.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy>=3.4.0->semantica==0.2.2) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (3.20.2)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->semantica==0.2.2) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->semantica==0.2.2) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->semantica==0.2.2) (0.7.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->semantica==0.2.2) (0.6.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.30->semantica==0.2.2) (5.0.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.20->fastembed>=0.2.0->semantica==0.2.2) (1.2.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (4.9.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.5.0->semantica==0.2.2) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa>=0.9.0->semantica==0.2.2) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.9.0->semantica==0.2.2) (4.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->semantica==0.2.2) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa>=0.9.0->semantica==0.2.2) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.17.0->semantica==0.2.2) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.4.0->semantica==0.2.2) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.4.0->semantica==0.2.2) (0.1.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.4.0->semantica==0.2.2) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.4.0->semantica==0.2.2) (7.5.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->semantica==0.2.2)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy>=3.4.0->semantica==0.2.2) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.9.0->semantica==0.2.2) (2.23)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.0->semantica==0.2.2) (0.2.14)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3.4.0->semantica==0.2.2) (2.0.1)
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 114.9 MB/s eta 0:00:00
# Downloading fastembed-0.7.4-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 11.9 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 18.2 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.0 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 109.5 MB/s eta 0:00:00
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 28.1 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 33.6 MB/s eta 0:00:00
# Downloading rdflib-7.5.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.2/587.2 kB 59.5 MB/s eta 0:00:00
# Downloading structlog-25.5.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.9 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading py_rust_stemmers-0.1.5-cp312-cp312-manylinux_2_28_x86_64.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.8/324.8 kB 37.0 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 116.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.2 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 104.4 MB/s eta 0:00:00
# Building wheels for collected packages: semantica
#   Building wheel for semantica (pyproject.toml) ... done
#   Created wheel for semantica: filename=semantica-0.2.2-py3-none-any.whl size=958522 sha256=f7d7db43a0128daae0e7ee19b10daeb87d5c275f2b13e5094aa4f385034a8832
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rf346xty/wheels/18/34/8e/a7de71fb50ff311a55615cec42567c1d13b16dc80ea550bf42
# Successfully built semantica
# Installing collected packages: py-rust-stemmers, widgetsnbextension, structlog, rdflib, python-docx, pypdf2, loguru, jedi, humanfriendly, faiss-cpu, comm, coloredlogs, onnxruntime, ipywidgets, fastembed, semantica
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed coloredlogs-15.0.1 comm-0.2.3 faiss-cpu-1.13.2 fastembed-0.7.4 humanfriendly-10.0 ipywidgets-8.1.8 jedi-0.19.2 loguru-0.7.3 onnxruntime-1.23.2 py-rust-stemmers-0.1.5 pypdf2-3.0.1 python-docx-1.2.0 rdflib-7.5.0 semantica-0.2.2 structlog-25.5.0 widgetsnbextension-4.0.15
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.9/282.9 kB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.3/223.3 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 114.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 46.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 94.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 56.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.0/345.0 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 1.8 MB/s eta 0:00:00
#   Building wheel for pylatexenc (setup.py) ... done

# %%
import os
os.environ["SEMANTICA_DISABLE_JUPYTER_PROGRESS"] = "1"

# %%
from getpass import getpass
from semantica.llms import Groq

GROQ_API_KEY = getpass("Enter your GROQ API key: ")

if not GROQ_API_KEY:
    raise ValueError("GROQ API key is required")

groq_llm = Groq(
    model="llama-3.1-8b-instant",
    api_key=GROQ_API_KEY,
)

print(f"✓ Groq LLM initialized: {groq_llm.model}")
# Out:
# WARNING:semantica.llms.litellm:litellm library not installed. Install with: pip install litellm
# Enter your GROQ API key: ··········
# ✓ Groq LLM initialized: llama-3.1-8b-instant

# %% [markdown]
# ## Step 1: Parse PDF with Docling
#
# Parse earnings call PDF and extract financial tables using DoclingParser.

# %%
import requests
from pathlib import Path
from semantica.parse import DoclingParser

parser = DoclingParser()

PRESS_RELEASE_URL = "https://filecache.investorroom.com/mr5ircnw_mda/677/MDA_Space_Ltd_Q3_2025_Press_Release_Nov_14_2025_FINAL.pdf"
TRANSCRIPT_URL = "https://filecache.investorroom.com/mr5ircnw_mda/681/MDA%20Space%20Ltd.%20Q3%202025%20Earnings%20Conference%20Call%20Transcript%20%28November%2014%202025%29.pdf"

download_dir = Path("downloads")
download_dir.mkdir(exist_ok=True)

press_release_pdf = download_dir / "mda_space_q3_2025_press_release.pdf"
transcript_pdf = download_dir / "mda_space_q3_2025_transcript.pdf"

if not press_release_pdf.exists():
    press_release_pdf.write_bytes(requests.get(PRESS_RELEASE_URL).content)

if not transcript_pdf.exists():
    transcript_pdf.write_bytes(requests.get(TRANSCRIPT_URL).content)

try:
    press_release = parser.parse(press_release_pdf)
    transcript = parser.parse(transcript_pdf)
except Exception as e:
    print("Parsing failed")
    print(e)
    print("Using fallback empty documents.")
    press_release = {"full_text": "", "tables": []}
    transcript = {"full_text": "", "tables": []}

parsed_doc = {
    "full_text": (
        "# Press Release\n\n"
        f"{press_release['full_text']}\n\n"
        "# Transcript\n\n"
        f"{transcript['full_text']}"
    ),
    "tables": press_release["tables"] + transcript["tables"],
    "metadata": {
        "title": "MDA Space Ltd. Q3 2025 Earnings Analysis",
        "company": "MDA Space Ltd.",
        "quarter": "Q3 2025",
        "date": "November 14, 2025",
    },
}

print("Parsing completed")
print("Documents processed: 2")
print("Tables extracted:", len(parsed_doc["tables"]))
# Out:
# 🔄 Semantica is parsing: Docling: mda_space_q3_2025_press_release.pdf 🔍 parse DoclingParser |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is parsing: Initializing Docling converter... 🔍 parse DoclingParser |█░░░░░░░░░░░░░░| 10.0% ETA: 0.0s Rate: 1068.9/s Time: 0.00s Extracted: -🔄 Semantica is parsing: Converting document with Docling (this may take a while for large PDFs)... 🔍 parse DoclingParser |███░░░░░░░░░░░░| 20.0% ETA: 0.0s Rate: 207.9/s Time: 0.01s Extracted: -
# [INFO] 2026-01-19 18:46:07,772 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-01-19 18:46:07,790 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-01-19 18:46:07,791 [RapidOCR] main.py:53: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-01-19 18:46:07,865 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-01-19 18:46:07,869 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-01-19 18:46:07,870 [RapidOCR] main.py:53: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-01-19 18:46:07,905 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-01-19 18:46:07,937 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-01-19 18:46:07,938 [RapidOCR] main.py:53: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.onnx
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 🔄 Semantica is parsing: Document conversion complete (34.9s), extracting content... 🔍 parse DoclingParser |██████████░░░░░| 70.0% ETA: 14.9s Rate: 0.2/s Time: 34.86s Extracted: -🔄 Semantica is parsing: Extracting text content (markdown format)... 🔍 parse DoclingParser |████████████░░░| 80.0% ETA: 8.7s Rate: 0.2/s Time: 34.87s Extracted: -🔄 Semantica is parsing: Extracting document metadata... 🔍 parse DoclingParser |████████████░░░| 80.0% ETA: 8.7s Rate: 0.2/s Time: 34.93s Extracted: -🔄 Semantica is parsing: Extracting tables from document... 🔍 parse DoclingParser |█████████████░░| 90.0% ETA: 3.9s Rate: 0.3/s Time: 34.93s Extracted: -🔄 Semantica is parsing: Extracting page structure... 🔍 parse DoclingParser |█████████████░░| 90.0% ETA: 3.9s Rate: 0.3/s Time: 34.96s Extracted: -✅ Semantica is parsing: Parsed document (Docling): 8 tables, 10 pages extracted 🔍 parse DoclingParser |███████████████| 100.0% ETA: - Rate: 0.3/s Time: 35.01s Extracted (Docling): 8 tables, 0 images, 10 pages🔄 Semantica is parsing: Initializing Docling converter... 🔍 parse DoclingParser |█░░░░░░░░░░░░░░| 10.0% ETA: 0.0s Rate: 8019.7/s Time: 0.00s Extracted: -🔄 Semantica is parsing: Converting document with Docling (this may take a while for large PDFs)... 🔍 parse DoclingParser |███░░░░░░░░░░░░| 20.0% ETA: 0.0s Rate: 1473.2/s Time: 0.00s Extracted: -🔄 Semantica is parsing: Document conversion complete (14.4s), extracting content... 🔍 parse DoclingParser |██████████░░░░░| 70.0% ETA: 6.2s Rate: 0.5/s Time: 14.45s Extracted: -🔄 Semantica is parsing: Extracting text content (markdown format)... 🔍 parse DoclingParser |████████████░░░| 80.0% ETA: 3.6s Rate: 0.6/s Time: 14.45s Extracted: -🔄 Semantica is parsing: Extracting document metadata... 🔍 parse DoclingParser |████████████░░░| 80.0% ETA: 3.6s Rate: 0.6/s Time: 14.49s Extracted: -🔄 Semantica is parsing: Extracting tables from document... 🔍 parse DoclingParser |█████████████░░| 90.0% ETA: 1.6s Rate: 0.6/s Time: 14.49s Extracted: -🔄 Semantica is parsing: Extracting page structure... 🔍 parse DoclingParser |█████████████░░| 90.0% ETA: 1.6s Rate: 0.6/s Time: 14.49s Extracted: -✅ Semantica is parsing: Parsed document (Docling): 37 pages extracted 🔍 parse DoclingParser |███████████████| 100.0% ETA: - Rate: 0.6/s Time: 14.52s Extracted (Docling): 0 tables, 0 images, 37 pagesParsing completed
# Documents processed: 2
# Tables extracted: 8

# %% [markdown]
# ## Step 2: Normalize Text
#
# Normalize extracted text using TextNormalizer for consistent processing.

# %%
from semantica.normalize import TextNormalizer

normalizer = TextNormalizer()

normalized_text = normalizer.normalize(
    parsed_doc["full_text"],
    clean_html=False,
    remove_extra_whitespace=False,
    lowercase=False,
)

print("Normalization completed")
print("Normalized text length:", len(normalized_text))
# Out:
# 🔄 Normalizing text 🔧 normalize TextNormalizer |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -Normalization completed
# Normalized text length: 85180

# %% [markdown]
# ## Step 3: Split Text into Chunks
#
# Split the normalized text into overlapping chunks to enable scalable and accurate entity and relation extraction.
# This step prepares the text for LLM-based semantic processing.

# %%
from semantica.split import TextSplitter

CHUNK_SIZE = 1000
CHUNK_OVERLAP = 250

splitter = TextSplitter(
    method="recursive",
    chunk_size=CHUNK_SIZE,
    chunk_overlap=CHUNK_OVERLAP,
)

chunks = splitter.split(normalized_text)

def get_chunk_text(chunk):
    return getattr(chunk, "content", getattr(chunk, "text", ""))

print("Chunking completed")
print("Total chunks:", len(chunks))
print("Sample chunk:")
print(get_chunk_text(chunks[0]))
# Out:
# Chunking completed
# Total chunks: 148
# Sample chunk:
# # Press Release
#
# ## NEWS RELEASE
#
# ## MDA SPACE REPORTS THIRD QUARTER 2025 RESULTS
#
# - Q3 2025 Highlights
# - o Backlog of $4.4 billion at quarter-end, provides revenue visibility for 2025 and beyond
# - o Revenues of $409.8 million, up 45% YoY
# - o Adjusted EBITDA 1 of $82.8 million, up 49% YoY, and adjusted EBITDA margin 1 of 20.2%
# - o Adjusted net income 1 of $46.1 million, up 33% YoY, and adjusted diluted earnings per share 1 of $0.35, up 25% YoY
# - o Operating cash flow of $32.8 million
# - o Net debt to adjusted EBITDA 1 ratio of 0.3x at quarter-end
# - Reaffirmed 2025 full-year financial outlook
#
# Brampton, Ontario (November 14, 2025) -- MDA Space Ltd. (TSX: MDA), a trusted space mission partner to the rapidly expanding global space industry, today announced its financial results for the third quarter ended September 30, 2025.

# %% [markdown]
# ## Step 4: Extract Entities
#
# Extract entities (organizations, people, financial terms) using NERExtractor with Groq LLM.

# %%
from semantica.semantic_extract import NERExtractor

ner = NERExtractor(
    method="llm",
    provider="groq",
    llm_model="llama-3.1-8b-instant",
    temperature=0.0,
    api_key=GROQ_API_KEY,
)

ENTITY_TYPES = ["ORGANIZATION", "PERSON", "MONEY", "PERCENT", "DATE", "EVENT"]

all_entities = [
    e
    for c in chunks
    for e in ner.extract_entities(
        get_chunk_text(c),
        entity_types=ENTITY_TYPES,
    )
    if get_chunk_text(c).strip()
]

print("Entities:", len(all_entities))
# Out:
# 🔄 Semantica is extracting: Extracting named entities from text 🎯 semantic_extract NERExtractor |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/706 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model_optimized.onnx:   0%|          | 0.00/66.5M [00:00<?, ?B/s]
# ✅ Semantica is extracting: Extracted 14 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 6.33s Extracted: -✅ Semantica is extracting: Extracted 9 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.10s Extracted: -✅ Semantica is extracting: Extracted 9 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.05s Extracted: -✅ Semantica is extracting: Extracted 15 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.05s Extracted: -✅ Semantica is extracting: Extracted 13 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.27s Extracted: -✅ Semantica is extracting: Extracted 10 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.83s Extracted: -✅ Semantica is extracting: Extracted 6 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.62s Extracted: -✅ Semantica is extracting: Extracted 10 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.07s Extracted: -✅ Semantica is extracting: Extracted 8 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.87s Extracted: -✅ Semantica is extracting: Extracted 5 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.65s Extracted: -✅ Semantica is extracting: Extracted 22 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.70s Extracted: -✅ Semantica is extracting: Extracted 14 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.21s Extracted: -✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.90s Extracted: -✅ Semantica is extracting: Extracted 8 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.86s Extracted: -✅ Semantica is extracting: Extracted 19 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.31s Extracted: -✅ Semantica is extracting: Extracted 16 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.42s Extracted: -✅ Semantica is extracting: Extracted 16 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.10s Extracted: -✅ Semantica is extracting: Extracted 11 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.20s Extracted: -✅ Semantica is extracting: Extracted 14 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.09s Extracted: -✅ Semantica is extracting: Extracted 14 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.76s Extracted: -✅ Semantica is extracting: Extracted 13 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.02s Extracted: -✅ Semantica is extracting: Extracted 16 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.16s Extracted: -✅ Semantica is extracting: Extracted 11 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.95s Extracted: -✅ Semantica is extracting: Extracted 6 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.64s Extracted: -✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.31s Extracted: -✅ Semantica is extracting: Extracted 4 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Ti ...

# %% [markdown]
# ## Step 5: Extract Financial Metrics
#
# Extract financial metrics (money, percentages, dates) from text and tables.

# %%
FINANCIAL_ENTITY_TYPES = [
    "MONEY", "CURRENCY", "PERCENT", "PERCENTAGE",
    "QUANTITY", "CARDINAL",
]

financial_entities = []

for chunk in chunks:
    text = get_chunk_text(chunk)
    if text.strip():
        financial_entities += ner.extract_entities(
            text,
            entity_types=FINANCIAL_ENTITY_TYPES,
        )

money, percentages, quantities = [], [], []

for e in financial_entities:
    label = e.label.upper()
    if label in ("MONEY", "CURRENCY"):
        money.append(e.text)
    elif label in ("PERCENT", "PERCENTAGE"):
        percentages.append(e.text)
    elif label in ("CARDINAL", "QUANTITY"):
        quantities.append(e.text)

print("\nFinancial entity extraction completed")
print("Total financial entities:", len(financial_entities))
print("Money:", len(money))
print("Percentages:", len(percentages))
print("Quantities:", len(quantities))

if financial_entities:
    print("Sample:", f"{financial_entities[0].text} ({financial_entities[0].label})")
# Out:
# ✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.03s Extracted: -✅ Semantica is extracting: Extracted 4 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.83s Extracted: -✅ Semantica is extracting: Extracted 4 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.49s Extracted: -✅ Semantica is extracting: Extracted 13 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.93s Extracted: -✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.08s Extracted: -✅ Semantica is extracting: Extracted 13 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.44s Extracted: -✅ Semantica is extracting: Extracted 6 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.55s Extracted: -✅ Semantica is extracting: Extracted 9 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.20s Extracted: -✅ Semantica is extracting: Extracted 6 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.57s Extracted: -✅ Semantica is extracting: Extracted 4 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.51s Extracted: -✅ Semantica is extracting: Extracted 25 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.77s Extracted: -✅ Semantica is extracting: Extracted 32 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.15s Extracted: -✅ Semantica is extracting: Extracted 23 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.40s Extracted: -✅ Semantica is extracting: Extracted 20 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.33s Extracted: -✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.06s Extracted: -✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.34s Extracted: -✅ Semantica is extracting: Extracted 9 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.85s Extracted: -✅ Semantica is extracting: Extracted 10 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.03s Extracted: -✅ Semantica is extracting: Extracted 12 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.79s Extracted: -✅ Semantica is extracting: Extracted 11 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.18s Extracted: -✅ Semantica is extracting: Extracted 13 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.23s Extracted: -✅ Semantica is extracting: Extracted 16 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.27s Extracted: -✅ Semantica is extracting: Extracted 9 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.23s Extracted: -✅ Semantica is extracting: Extracted 21 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.58s Extracted: -✅ Semantica is extracting: Extracted 18 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.74s Extracted: -✅ Semantica is extracting: Extracted 3 entities using llm 🎯 semantic_extract NERExtractor |███████████████| 100.0% ETA: - Rate: - Tim ...
# Financial entity extraction completed
# Total financial entities: 4726
# Money: 767
# Percentages: 485
# Quantities: 2031
# Sample: $4.4 billion (MONEY)

# %% [markdown]
# ## Step 5: Extract Relationships
#
# Extract relationships between entities using RelationExtractor with Groq LLM.

# %%
from concurrent.futures import ThreadPoolExecutor, TimeoutError
from semantica.semantic_extract import RelationExtractor

MAX_ENTITIES = 30
CHUNK_TIMEOUT = 60

relation_extractor = RelationExtractor(
    method="llm",
    confidence_threshold=0.6,
    relation_types=[
        "HAS_REVENUE",
        "HAS_GROWTH",
        "REPORTS",
        "PROVIDES_GUIDANCE",
        "IN_QUARTER",
        "FOR_PERIOD",
        "RELATED_TO",
    ],
    provider="groq",
    llm_model="llama-3.1-8b-instant",
    api_key=GROQ_API_KEY,
    temperature=0.0,
    verbose=False,
)


def filter_entities(text, entities):
    t = text.lower()
    return [e for e in entities if e.text.lower() in t]


def process_chunk(idx, chunk, total):
    text = get_chunk_text(chunk).strip()

    remaining = total - (idx + 1)

    if not text:
        print(f"Chunk {idx+1}/{total} | remaining {remaining} | skipped (empty)")
        return []

    chunk_entities = filter_entities(text, all_entities)[:MAX_ENTITIES]

    if len(chunk_entities) < 2:
        print(
            f"Chunk {idx+1}/{total} | remaining {remaining} | "
            f"skipped (entities={len(chunk_entities)})"
        )
        return []

    print(
        f"Chunk {idx+1}/{total} | remaining {remaining} | "
        f"entities={len(chunk_entities)}"
    )

    return relation_extractor.extract_relations(
        text=text,
        entities=chunk_entities,
        verbose=False,
    )


relationships = []
total_chunks = len(chunks)

with ThreadPoolExecutor(max_workers=1) as executor:
    for i, c in enumerate(chunks):
        future = executor.submit(process_chunk, i, c, total_chunks)

        try:
            rels = future.result(timeout=CHUNK_TIMEOUT)
            relationships.extend(rels)
            print(f"  relations={len(rels)}")

        except TimeoutError:
            remaining = total_chunks - (i + 1)
            print(
                f"Chunk {i+1}/{total_chunks} | remaining {remaining} | timed out"
            )

        except Exception as e:
            remaining = total_chunks - (i + 1)
            print(
                f"Chunk {i+1}/{total_chunks} | remaining {remaining} | failed: {e}"
            )

print(f"Done {total_chunks}/{total_chunks}")
print(f"Total relationships: {len(relationships)}")

if relationships:
    for r in relationships[:10]:
        print(f"{r.subject.text} → {r.predicate} → {r.object.text}")
# Out:
# Chunk 1/148 | remaining 147 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.65s Extracted: -  relations=9
# Chunk 2/148 | remaining 146 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.81s Extracted: -  relations=4
# Chunk 3/148 | remaining 145 | entities=30
# ✅ Semantica is extracting: Extracted 11 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.07s Extracted: -  relations=11
# Chunk 4/148 | remaining 144 | entities=30
# ✅ Semantica is extracting: Extracted 13 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.78s Extracted: -  relations=13
# Chunk 5/148 | remaining 143 | entities=30
# ✅ Semantica is extracting: Extracted 194 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 9.45s Extracted: -  relations=194
# Chunk 6/148 | remaining 142 | entities=30
# ✅ Semantica is extracting: Extracted 11 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.50s Extracted: -  relations=11
# Chunk 7/148 | remaining 141 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.35s Extracted: -  relations=7
# Chunk 8/148 | remaining 140 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.27s Extracted: -  relations=7
# Chunk 9/148 | remaining 139 | entities=30
# ✅ Semantica is extracting: Extracted 12 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.94s Extracted: -  relations=12
# Chunk 10/148 | remaining 138 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.24s Extracted: -  relations=5
# Chunk 11/148 | remaining 137 | entities=30
# Chunk 11/148 | remaining 137 | timed out
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 77.35s Extracted: -Chunk 12/148 | remaining 136 | entities=30
# ✅ Semantica is extracting: Extracted 17 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.32s Extracted: -  relations=17
# Chunk 13/148 | remaining 135 | entities=30
# ✅ Semantica is extracting: Extracted 17 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.10s Extracted: -  relations=17
# Chunk 14/148 | remaining 134 | entities=30
# ✅ Semantica is extracting: Extracted 14 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.19s Extracted: -  relations=14
# Chunk 15/148 | remaining 133 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.16s Extracted: -  relations=8
# Chunk 16/148 | remaining 132 | entities=30
# Chunk 16/148 | remaining 132 | timed out
# Chunk 17/148 | remaining 131 | timed out
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 122.63s Extracted: -Chunk 17/148 | remaining 131 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 4.58s Extracted: -Chunk 18/148 | remaining 130 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.48s Extracted: -  relations=5
# Chunk 19/148 | remaining 129 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.67s Extracted: -  relations=5
# Chunk 20/148 | remaining 128 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.99s Extracted: -  relations=9
# Chunk 21/148 | remaining 127 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.06s Extracted: -  relations=5
# Chunk 22/148 | remaining 126 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.91s Extracted: -  relations=9
# Chunk 23/148 | remaining 125 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.15s Extracted: -  relations=2
# Chunk 24/148 | remaining 124 | entities=30
# ✅ Semantica is extracting: Extracted 11 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.14s Extracted: -  relations=11
# Chunk 25/148 | remaining 123 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.65s Extracted: -  relations=4
# Chunk 26/148 | remaining 122 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 4.27s Extracted: -  relations=435
# Chunk 27/148 | remaining 121 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.29s Extracted: -  relations=9
# Chunk 28/148 | remaining 120 | entities=30
# ✅ Semantica is extracting: Extracted 25 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.48s Extracted: -  relations=25
# Chunk 29/148 | remaining 119 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.26s Extracted: -  relations=5
# Chunk 30/148 | remaining 118 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.78s Extracted: -  relations=3
# Chunk 31/148 | remaining 117 | entities=23
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.72s Extracted: -  relations=6
# Chunk 32/148 | remaining 116 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.83s Extracted: -  relations=3
# Chunk 33/148 | remaining 115 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.91s Extracted: -  relations=9
# Chunk 34/148 | remaining 114 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.16s Extracted: -  relations=4
# Chunk 35/148 | remaining 113 | entities=30
# ✅ Semantica is extracting: Extracted 12 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.66s Extracted: -  relations=12
# Chunk 36/148 | remaining 112 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 17.17s Extracted: -  relations=8
# Chunk 37/148 | remaining 111 | entities=30
# ✅ Semantica is extracting: Extracted 11 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.14s Extracted: -  relations=11
# Chunk 38/148 | remaining 110 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.70s Extracted: -  relations=6
# Chunk 39/148 | remaining 109 | entities=30
# ✅ Semantica is extracting: Extracted 20 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 6.49s Extracted: -  relations=20
# Chunk 40/148 | remaining 108 | entities=30
# ✅ Semantica is extracting: Extracted 31 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 39.67s Extracted: -  relations=31
# Chunk 41/148 | remaining 107 | entities=30
# ✅ Semantica is extracting: Extracted 12 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.72s Extracted: -  relations=12
# Chunk 42/148 | remaining 106 | entities=30
# ✅ Semantica is extracting: Extracted 10 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.29s Extracted: -  relations=10
# Chunk 43/148 | remaining 105 | entities=30
# ✅ Semantica is extracting: Extracted 17 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 7.92s Extracted: -  relations=17
# Chunk 44/148 | remaining 104 | entities=30
# ✅ Semantica is extracting: Extracted 10 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 22.87s Extracted: -  relations=10
# Chunk 45/148 | remaining 103 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.15s Extracted: -  relations=8
# Chunk 46/148 | remaining 102 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 9.80s Extracted: -  relations=4
# Chunk 47/148 | remaining 101 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.19s Extracted: -  relations=8
# Chunk 48/148 | remaining 100 | entities=30
# ✅ Semantica is extracting: Extracted 188 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 35.21s Extracted: -  relations=188
# Chunk 49/148 | remaining 99 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.12s Extracted: -  relations=8
# Chunk 50/148 | remaining 98 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.35s Extracted: -  relations=4
# Chunk 51/148 | remaining 97 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.69s Extracted: -  relations=5
# Chunk 52/148 | remaining 96 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.29s Extracted: -  relations=4
# Chunk 53/148 | remaining 95 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.61s Extracted: -  relations=7
# Chunk 54/148 | remaining 94 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.74s Extracted: -  relations=3
# Chunk 55/148 | remaining 93 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.50s Extracted: -  relations=5
# Chunk 56/148 | remaining 92 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.92s Extracted: -  relations=9
# Chunk 57/148 | remaining 91 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.40s Extracted: -  relations=435
# Chunk 58/148 | remaining 90 | entities=30
# ✅ Semantica is extracting: Extracted 209 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 10.13s Extracted: -  relations=209
# Chunk 59/148 | remaining 89 | entities=30
# ✅ Semantica is extracting: Extracted 222 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 8.85s Extracted: -  relations=222
# Chunk 60/148 | remaining 88 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.23s Extracted: -  relations=435
# Chunk 61/148 | remaining 87 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.02s Extracted: -  relations=1
# Chunk 62/148 | remaining 86 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.39s Extracted: -  relations=1
# Chunk 63/148 | remaining 85 | entities=26
# ✅ Semantica is extracting: Extracted 11 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.59s Extracted: -  relations=11
# Chunk 64/148 | remaining 84 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.66s Extracted: -  relations=8
# Chunk 65/148 | remaining 83 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.77s Extracted: -  relations=5
# Chunk 66/148 | remaining 82 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 4.44s Extracted: -  relations=7
# Chunk 67/148 | remaining 81 | entities=30
# ✅ Semantica is extracting: Extracted 19 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.13s Extracted: -  relations=19
# Chunk 68/148 | remaining 80 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 7.50s Extracted: -  relations=435
# Chunk 69/148 | remaining 79 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.81s Extracted: -  relations=2
# Chunk 70/148 | remaining 78 | entities=30
# ✅ Semantica is extracting: Extracted 10 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.46s Extracted: -  relations=10
# Chunk 71/148 | remaining 77 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.74s Extracted: -  relations=1
# Chunk 72/148 | remaining 76 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.68s Extracted: -  relations=8
# Chunk 73/148 | remaining 75 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.52s Extracted: -  relations=7
# Chunk 74/148 | remaining 74 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.92s Extracted: -  relations=435
# Chunk 75/148 | remaining 73 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.91s Extracted: -  relations=435
# Chunk 76/148 | remaining 72 | entities=30
# ✅ Semantica is extracting: Extracted 11 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.72s Extracted: -  relations=11
# Chunk 77/148 | remaining 71 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.59s Extracted: -  relations=2
# Chunk 78/148 | remaining 70 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.30s Extracted: -  relations=3
# Chunk 79/148 | remaining 69 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.50s Extracted: -  relations=3
# Chunk 80/148 | remaining 68 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 4.15s Extracted: -  relations=6
# Chunk 81/148 | remaining 67 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 6.51s Extracted: -  relations=435
# Chunk 82/148 | remaining 66 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.93s Extracted: -  relations=3
# Chunk 83/148 | remaining 65 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.47s Extracted: -  relations=4
# Chunk 84/148 | remaining 64 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.08s Extracted: -  relations=5
# Chunk 85/148 | remaining 63 | entities=30
# ✅ Semantica is extracting: Extracted 13 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.56s Extracted: -  relations=13
# Chunk 86/148 | remaining 62 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.56s Extracted: -  relations=2
# Chunk 87/148 | remaining 61 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.67s Extracted: -  relations=3
# Chunk 88/148 | remaining 60 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 4.16s Extracted: -  relations=435
# Chunk 89/148 | remaining 59 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.09s Extracted: -  relations=1
# Chunk 90/148 | remaining 58 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 48.40s Extracted: -  relations=1
# Chunk 91/148 | remaining 57 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.58s Extracted: -  relations=7
# Chunk 92/148 | remaining 56 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.15s Extracted: -  relations=6
# Chunk 93/148 | remaining 55 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.75s Extracted: -  relations=3
# Chunk 94/148 | remaining 54 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.70s Extracted: -  relations=9
# Chunk 95/148 | remaining 53 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.96s Extracted: -  relations=8
# Chunk 96/148 | remaining 52 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.75s Extracted: -  relations=7
# Chunk 97/148 | remaining 51 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.76s Extracted: -  relations=4
# Chunk 98/148 | remaining 50 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.68s Extracted: -  relations=6
# Chunk 99/148 | remaining 49 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.58s Extracted: -  relations=5
# Chunk 100/148 | remaining 48 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.08s Extracted: -  relations=9
# Chunk 101/148 | remaining 47 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.62s Extracted: -  relations=6
# Chunk 102/148 | remaining 46 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.88s Extracted: -  relations=7
# Chunk 103/148 | remaining 45 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.25s Extracted: -  relations=8
# Chunk 104/148 | remaining 44 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.18s Extracted: -  relations=3
# Chunk 105/148 | remaining 43 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 7.27s Extracted: -  relations=435
# Chunk 106/148 | remaining 42 | entities=30
# ✅ Semantica is extracting: Extracted 67 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 27.55s Extracted: -  relations=67
# Chunk 107/148 | remaining 41 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.81s Extracted: -  relations=6
# Chunk 108/148 | remaining 40 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.91s Extracted: -  relations=4
# Chunk 109/148 | remaining 39 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 4.30s Extracted: -  relations=2
# Chunk 110/148 | remaining 38 | entities=30
# ✅ Semantica is extracting: Extracted 8 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.03s Extracted: -  relations=8
# Chunk 111/148 | remaining 37 | entities=30
# ✅ Semantica is extracting: Extracted 9 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.51s Extracted: -  relations=9
# Chunk 112/148 | remaining 36 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.94s Extracted: -  relations=4
# Chunk 113/148 | remaining 35 | entities=30
# WARNING:semantica.provider_GroqProvider:Schema validation failed (attempt 1): 1 validation error for RelationsResponse
# relations.1.object
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type. Retrying with error feedback...
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.58s Extracted: -  relations=2
# Chunk 114/148 | remaining 34 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.38s Extracted: -  relations=4
# Chunk 115/148 | remaining 33 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.97s Extracted: -  relations=2
# Chunk 116/148 | remaining 32 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.93s Extracted: -  relations=3
# Chunk 117/148 | remaining 31 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.46s Extracted: -  relations=1
# Chunk 118/148 | remaining 30 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.63s Extracted: -  relations=4
# Chunk 119/148 | remaining 29 | entities=30
# WARNING:semantica.provider_GroqProvider:Schema validation failed (attempt 1): 4 validation errors for RelationsResponse
# relations.1.object
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# relations.2.object
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# relations.7.object
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# relations.8.object
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type. Retrying with error feedback...
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.20s Extracted: -  relations=7
# Chunk 120/148 | remaining 28 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.65s Extracted: -  relations=4
# Chunk 121/148 | remaining 27 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.66s Extracted: -  relations=3
# Chunk 122/148 | remaining 26 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.35s Extracted: -  relations=7
# Chunk 123/148 | remaining 25 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.65s Extracted: -  relations=2
# Chunk 124/148 | remaining 24 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.93s Extracted: -  relations=2
# Chunk 125/148 | remaining 23 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.30s Extracted: -  relations=3
# Chunk 126/148 | remaining 22 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.79s Extracted: -  relations=5
# Chunk 127/148 | remaining 21 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.06s Extracted: -  relations=1
# Chunk 128/148 | remaining 20 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.76s Extracted: -  relations=4
# Chunk 129/148 | remaining 19 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.44s Extracted: -  relations=4
# Chunk 130/148 | remaining 18 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.86s Extracted: -  relations=1
# Chunk 131/148 | remaining 17 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.72s Extracted: -  relations=4
# Chunk 132/148 | remaining 16 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.07s Extracted: -  relations=4
# Chunk 133/148 | remaining 15 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.93s Extracted: -  relations=7
# Chunk 134/148 | remaining 14 | entities=30
# ✅ Semantica is extracting: Extracted 4 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.25s Extracted: -  relations=4
# Chunk 135/148 | remaining 13 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.13s Extracted: -  relations=435
# Chunk 136/148 | remaining 12 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.47s Extracted: -  relations=2
# Chunk 137/148 | remaining 11 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.78s Extracted: -  relations=435
# Chunk 138/148 | remaining 10 | entities=30
# ✅ Semantica is extracting: Extracted 5 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 2.49s Extracted: -  relations=5
# Chunk 139/148 | remaining 9 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.51s Extracted: -  relations=2
# Chunk 140/148 | remaining 8 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.06s Extracted: -  relations=2
# Chunk 141/148 | remaining 7 | entities=30
# ✅ Semantica is extracting: Extracted 435 relations 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 5.27s Extracted: -  relations=435
# Chunk 142/148 | remaining 6 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.52s Extracted: -  relations=7
# Chunk 143/148 | remaining 5 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 3.68s Extracted: -  relations=3
# Chunk 144/148 | remaining 4 | entities=30
# ✅ Semantica is extracting: Extracted 3 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.79s Extracted: -  relations=3
# Chunk 145/148 | remaining 3 | entities=30
# ✅ Semantica is extracting: Extracted 6 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.25s Extracted: -  relations=6
# Chunk 146/148 | remaining 2 | entities=30
# ✅ Semantica is extracting: Extracted 2 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.32s Extracted: -  relations=2
# Chunk 147/148 | remaining 1 | entities=30
# ✅ Semantica is extracting: Extracted 7 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 0.98s Extracted: -  relations=7
# Chunk 148/148 | remaining 0 | entities=30
# ✅ Semantica is extracting: Extracted 1 relations using llm 🎯 semantic_extract RelationExtractor |███████████████| 100.0% ETA: - Rate: - Time: 1.38s Extracted: -  relations=1
# Done 148/148
# Total relationships: 6927
# MDA Space Ltd. → HAS_REVENUE → $409.8 million
# MDA Space Ltd. → HAS_GROWTH → 20.2%
# MDA Space Ltd. → HAS_REVENUE → $4.4 billion
# MDA Space Ltd. → HAS_GROWTH → 20.2%
# MDA Space Ltd. → HAS_GROWTH → 0.3x
# MDA Space Ltd. → REPORTS → Q3 2025
# MDA Space Ltd. → PROVIDES_GUIDANCE → 2025
# MDA Space Ltd. → IN_QUARTER → Q3 2025
# MDA Space Ltd. → FOR_PERIOD → 2025
# MDA Space Ltd. → REPORTS → September 30, 2025

# %% [markdown]
# ## Step 6: Detect Conflicts
#
# Detect conflicts in extracted entities and relationships using ConflictDetector.

# %%
from semantica.conflicts import SourceTracker, SourceReference, ConflictDetector

source_tracker = SourceTracker()

conflict_detector = ConflictDetector(
    source_tracker=source_tracker,
    similarity_threshold=0.8,
    confidence_threshold=0.7,
)

entities = all_entities
extracted_relationships = relationships

for e in entities:
    entity_id = getattr(e, "id", None) or e.text
    source_tracker.track_property_source(
        entity_id=entity_id,
        property_name="name",
        value=e.text,
        source=SourceReference(
            document="earnings_call",
            timestamp="2024-Q1",
            metadata={"entity_type": getattr(e, "label", "UNKNOWN")},
        ),
    )

entity_records = [
    {
        "id": getattr(e, "id", None) or e.text,
        "name": e.text,
    }
    for e in entities
]

entity_value_conflicts = conflict_detector.detect_value_conflicts(
    entity_records,
    property_name="name",
)

normalized_relationships = [
    {
        "id": getattr(r, "id", None),
        "source_id": getattr(r.subject, "id", None) or r.subject.text,
        "target_id": getattr(r.object, "id", None) or r.object.text,
        "type": r.predicate,
        "confidence": getattr(r, "confidence", 1.0),
        "metadata": {},
    }
    for r in extracted_relationships
]

relationship_conflicts = conflict_detector.detect_relationship_conflicts(
    normalized_relationships
)

print("Conflict detection completed")
print("Entity value conflicts:", len(entity_value_conflicts))
print("Relationship conflicts:", len(relationship_conflicts))

if entity_value_conflicts:
    print("\nSample entity conflict:")
    print(entity_value_conflicts[0])

if relationship_conflicts:
    print("\nSample relationship conflict:")
    print(relationship_conflicts[0])
# Out:
# 🔄 Semantica is resolving: Analyzing entities... 0/3482 (remaining: 3482) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 1/3482 (remaining: 3481) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.0% ETA: 1.8s Rate: 1822.0/s Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 10/3482 (remaining: 3472) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.3% ETA: 1.0s Rate: 3408.3/s Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 20/3482 (remaining: 3462) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.6% ETA: 0.6s Rate: 5328.5/s Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 30/3482 (remaining: 3452) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.9% ETA: 0.5s Rate: 6575.2/s Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 40/3482 (remaining: 3442) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 1.1% ETA: 0.5s Rate: 6769.6/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 50/3482 (remaining: 3432) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 1.4% ETA: 0.4s Rate: 7619.4/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 60/3482 (remaining: 3422) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 1.7% ETA: 0.4s Rate: 8410.8/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 70/3482 (remaining: 3412) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 2.0% ETA: 0.4s Rate: 9117.2/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 80/3482 (remaining: 3402) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 2.3% ETA: 0.3s Rate: 9890.5/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 90/3482 (remaining: 3392) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 2.6% ETA: 0.3s Rate: 10094.3/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 100/3482 (remaining: 3382) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 2.9% ETA: 0.3s Rate: 10042.4/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 110/3482 (remaining: 3372) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 3.2% ETA: 0.3s Rate: 10112.7/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 120/3482 (remaining: 3362) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 3.4% ETA: 0.3s Rate: 10477.7/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 130/3482 (remaining: 3352) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 3.7% ETA: 0.3s Rate: 10877.6/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 140/3482 (remaining: 3342) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 4.0% ETA: 0.3s Rate: 11112.0/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 150/3482 (remaining: 3332) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 4.3% ETA: 0.3s Rate: 10512.2/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 160/3482 (remaining: 3322) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 4.6% ETA: 0.3s Rate: 10887.9/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 170/3482 (remaining: 3312) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 4.9% ETA: 0.3s Rate: 11142.5/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 180/3482 (remaining: 3302) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 5.2% ETA: 0.3s Rate: 11398.6/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 190/3482 (remaining: 3292) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 5.5% ETA: 0.3s Rate: 11610.1/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 200/3482 (remaining: 3282) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 5.7% ETA: 0.3s Rate: 11798.7/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 210/3482 (remaining: 3272) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░ ...
# Entity value conflicts: 0
# Relationship conflicts: 58
#
# Sample relationship conflict:
# Conflict(conflict_id='MDA Space Ltd._2025_PROVIDES_GUIDANCE_confidence_conflict', conflict_type=<ConflictType.RELATIONSHIP_CONFLICT: 'relationship_conflict'>, entity_id=None, property_name='confidence', relationship_id='MDA Space Ltd._2025_PROVIDES_GUIDANCE', conflicting_values=[0.975, 0.95, 0.975, 0.925], sources=[], confidence=0.8, severity='medium', recommended_action='Review relationship definition', metadata={})

# %% [markdown]
# ## Step 7: Resolve Conflicts
#
# Resolve detected conflicts using ConflictResolver with voting strategy.

# %%
from semantica.conflicts import ConflictResolver

conflict_resolver = ConflictResolver(
    default_strategy="voting",
    source_tracker=source_tracker,
)

resolved_entity_value_conflicts = []
resolved_relationship_conflicts = []

for conflict in entity_value_conflicts:
    resolved_entity_value_conflicts.append(
        conflict_resolver.resolve_conflict(
            conflict,
            strategy="voting",
        )
    )

for conflict in relationship_conflicts:
    resolved_relationship_conflicts.append(
        conflict_resolver.resolve_conflict(
            conflict,
            strategy="voting",
        )
    )

print("Conflict resolution completed")
print("Entity value conflicts resolved:", len(resolved_entity_value_conflicts))
print("Relationship conflicts resolved:", len(resolved_relationship_conflicts))

if resolved_entity_value_conflicts:
    print("\nSample resolved entity conflict:")
    print(resolved_entity_value_conflicts[0])

if resolved_relationship_conflicts:
    print("\nSample resolved relationship conflict:")
    print(resolved_relationship_conflicts[0])
# Out:
# Conflict resolution completed
# Entity value conflicts resolved: 0
# Relationship conflicts resolved: 58
#
# Sample resolved relationship conflict:
# ResolutionResult(conflict_id='MDA Space Ltd._2025_PROVIDES_GUIDANCE_confidence_conflict', resolved=True, resolved_value=0.975, resolution_strategy='voting', confidence=0.5, sources_used=[], resolution_notes='Resolved by voting: 2/4 votes for this value', metadata={'conflict_type': 'relationship_conflict', 'entity_id': None, 'property_name': 'confidence', 'relationship_id': 'MDA Space Ltd._2025_PROVIDES_GUIDANCE'})

# %% [markdown]
# ## Step 8: Deduplicate Entities
#
# Detect and merge duplicate entities using DuplicateDetector and EntityMerger.

# %%
from semantica.deduplication import DuplicateDetector, EntityMerger
import time

start_time = time.time()

raw = []
for i, e in enumerate(entities):
    raw.append({
        "id": getattr(e, "id", None) or f"entity_{i}_{getattr(e, 'text', str(e))}",
        "name": (getattr(e, "text", getattr(e, "name", "")) or "").strip(),
        "type": getattr(e, "label", "UNKNOWN"),
        "confidence": float(getattr(e, "confidence", 1.0) or 1.0),
        "metadata": getattr(e, "metadata", {}),
    })

filtered = [r for r in raw if r["name"] and len(r["name"]) >= 3]

collapsed = {}
for ent in filtered:
    key = (ent["type"], ent["name"].lower())
    best = collapsed.get(key)
    if best is None or ent["confidence"] > best["confidence"]:
        collapsed[key] = ent

entity_dicts = list(collapsed.values())

detector = DuplicateDetector(
    similarity_threshold=0.96,
    confidence_threshold=0.92,
    use_clustering=True,
)

detector.detect_duplicate_groups(entity_dicts)

merger = EntityMerger(
    preserve_provenance=True,
    detector={
        "similarity_threshold": 0.96,
        "confidence_threshold": 0.92,
        "use_clustering": True,
    },
    strategy={"default_strategy": "keep_most_complete"},
)

merge_operations = merger.merge_duplicates(
    entities=entity_dicts,
    strategy="keep_most_complete",
)

deduplicated_entities = [op.merged_entity for op in merge_operations] or entity_dicts

entity_id_mapping = {}
for op in merge_operations:
    mid = op.merged_entity["id"]
    for sid in op.source_ids:
        entity_id_mapping[sid] = mid

deduplicated_relationships = []
for rel in normalized_relationships:
    s = entity_id_mapping.get(rel["source_id"], rel["source_id"])
    t = entity_id_mapping.get(rel["target_id"], rel["target_id"])
    if s != t:
        r = rel.copy()
        r["source_id"], r["target_id"] = s, t
        deduplicated_relationships.append(r)

print({
    "time_seconds": round(time.time() - start_time, 2),
    "entities_in": len(raw),
    "entities_after_filter": len(filtered),
    "entities_after_exact": len(entity_dicts),
    "entities_out": len(deduplicated_entities),
    "duplicates_removed": len(entity_dicts) - len(deduplicated_entities),
    "relationships_updated": len(deduplicated_relationships),
})
# Out:
# 🔄 Semantica is deduplicating: Detecting duplicate groups from 697 entities 🔄 deduplication DuplicateDetector |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block 'm'... 100/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 0.6% ETA: 0.9s Rate: 16710.4/s Time: 0.01s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block 'm'... 200/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 1.3% ETA: 0.7s Rate: 20622.0/s Time: 0.01s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block 'm'... 300/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 1.9% ETA: 0.8s Rate: 19233.5/s Time: 0.02s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block 'n'... 400/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 2.6% ETA: 0.8s Rate: 19057.4/s Time: 0.02s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block 'n'... 500/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 3.2% ETA: 0.8s Rate: 18393.3/s Time: 0.03s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 600/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 3.9% ETA: 0.8s Rate: 19543.2/s Time: 0.03s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 700/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 4.5% ETA: 0.7s Rate: 20481.3/s Time: 0.03s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 800/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 5.1% ETA: 0.7s Rate: 21469.1/s Time: 0.04s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 900/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 5.8% ETA: 0.6s Rate: 22659.4/s Time: 0.04s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 1000/15575 🔄 deduplication SimilarityCalculator |░░░░░░░░░░░░░░░| 6.4% ETA: 0.6s Rate: 23331.0/s Time: 0.04s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 1100/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 7.1% ETA: 0.6s Rate: 23414.6/s Time: 0.05s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 1200/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 7.7% ETA: 0.6s Rate: 23857.1/s Time: 0.05s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '2'... 1300/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 8.3% ETA: 0.6s Rate: 24272.9/s Time: 0.05s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 1400/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 9.0% ETA: 0.6s Rate: 24096.9/s Time: 0.06s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 1500/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 9.6% ETA: 0.6s Rate: 23819.1/s Time: 0.06s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 1600/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 10.3% ETA: 0.6s Rate: 24357.2/s Time: 0.07s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 1700/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 10.9% ETA: 0.6s Rate: 24651.6/s Time: 0.07s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 1800/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 11.6% ETA: 0.6s Rate: 24982.0/s Time: 0.07s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 1900/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 12.2% ETA: 0.5s Rate: 25389.9/s Time: 0.07s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 2000/15575 🔄 deduplication SimilarityCalculator |█░░░░░░░░░░░░░░| 12.8% ETA: 0.5s Rate: 25700.5/s Time: 0.08s Extracted: -🔄 Semantica is deduplicating: Comparing pairs in block '$'... 2100/15575 🔄 deduplication SimilarityCalculator |██░░░░░░░░░░░░░| 13.5% ETA: 0.5s Rate: 25886.4/s Time: 0.08s E ...

# %% [markdown]
# ## Step 9: Build Knowledge Graph
#
# Build knowledge graph from cleaned entities, relationships, and triplets using GraphBuilder.

# %%
from semantica.kg import GraphBuilder

# Deduplication is already done; avoid additional entity resolution/merging
graph_builder = GraphBuilder(
    merge_entities=False,
    entity_resolution_strategy="none",
)

final_relationships = deduplicated_relationships

kg_data = {
    "entities": deduplicated_entities,
    "relationships": final_relationships,
    "metadata": {
        "source": "earnings_call_transcript",
        "extraction_method": "Groq LLM",
    },
}

knowledge_graph = graph_builder.build(
    sources=[kg_data],
    merge_entities=False,
)

print("Knowledge graph build completed (no additional merging)")
print("Final entities:", len(knowledge_graph.get("entities", [])))
print("Final relationships:", len(knowledge_graph.get("relationships", [])))
# Out:
# 🔄 Semantica is building: Knowledge graph from 1 source(s) 🧠 kg GraphBuilder |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is building: Processing entities... 100/697 🧠 kg GraphBuilder |██░░░░░░░░░░░░░| 14.3% ETA: 0.0s Rate: 795883.1/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing entities... 200/697 🧠 kg GraphBuilder |████░░░░░░░░░░░| 28.7% ETA: 0.0s Rate: 96698.7/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing entities... 300/697 🧠 kg GraphBuilder |██████░░░░░░░░░| 43.0% ETA: 0.0s Rate: 96045.4/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing entities... 400/697 🧠 kg GraphBuilder |████████░░░░░░░| 57.4% ETA: 0.0s Rate: 106902.1/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing entities... 500/697 🧠 kg GraphBuilder |██████████░░░░░| 71.7% ETA: 0.0s Rate: 91936.0/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing entities... 600/697 🧠 kg GraphBuilder |████████████░░░| 86.1% ETA: 0.0s Rate: 87378.3/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing entities... 697/697 🧠 kg GraphBuilder |███████████████| 100.0% ETA: - Rate: 86140.3/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 241/4822 🧠 kg GraphBuilder |░░░░░░░░░░░░░░░| 5.0% ETA: 0.0s Rate: 478384.9/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing relationships... 482/4822 🧠 kg GraphBuilder |█░░░░░░░░░░░░░░| 10.0% ETA: 0.0s Rate: 346886.5/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing relationships... 723/4822 🧠 kg GraphBuilder |██░░░░░░░░░░░░░| 15.0% ETA: 0.0s Rate: 251033.3/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing relationships... 964/4822 🧠 kg GraphBuilder |██░░░░░░░░░░░░░| 20.0% ETA: 0.0s Rate: 217780.3/s Time: 0.00s Extracted: -🔄 Semantica is building: Processing relationships... 1205/4822 🧠 kg GraphBuilder |███░░░░░░░░░░░░| 25.0% ETA: 0.0s Rate: 219211.3/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 1446/4822 🧠 kg GraphBuilder |████░░░░░░░░░░░| 30.0% ETA: 0.0s Rate: 213992.1/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 1687/4822 🧠 kg GraphBuilder |█████░░░░░░░░░░| 35.0% ETA: 0.0s Rate: 197306.1/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 1928/4822 🧠 kg GraphBuilder |█████░░░░░░░░░░| 40.0% ETA: 0.0s Rate: 199768.2/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 2169/4822 🧠 kg GraphBuilder |██████░░░░░░░░░| 45.0% ETA: 0.0s Rate: 198981.7/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 2410/4822 🧠 kg GraphBuilder |███████░░░░░░░░| 50.0% ETA: 0.0s Rate: 193138.2/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 2651/4822 🧠 kg GraphBuilder |████████░░░░░░░| 55.0% ETA: 0.0s Rate: 194512.3/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 2892/4822 🧠 kg GraphBuilder |████████░░░░░░░| 60.0% ETA: 0.0s Rate: 194094.4/s Time: 0.01s Extracted: -🔄 Semantica is building: Processing relationships... 3133/4822 🧠 kg GraphBuilder |█████████░░░░░░| 65.0% ETA: 0.0s Rate: 196441.5/s Time: 0.02s Extracted: -🔄 Semantica is building: Processing relationships... 3374/4822 🧠 kg GraphBuilder |██████████░░░░░| 70.0% ETA: 0.0s Rate: 187069.0/s Time: 0.02s Extracted: -🔄 Semantica is building: Processing relationships... 3615/4822 🧠 kg GraphBuilder |███████████░░░░| 75.0% ETA: 0.0s Rate: 191220.0/s Time: 0.02s Extracted: -🔄 Semantica is building: Processing relationships... 3856/4822 🧠 kg GraphBuilder |███████████░░░░| 80.0% ETA: 0.0s Rate: 183208.0/s Time: 0.02s Extracted: -🔄 Semantica is building: Processing relationships... 4097/4822 🧠 kg GraphBuilder |████████████░░░| 85.0% ETA: 0.0s Rate: 186085.5/s Time: 0.02s Extracted: -🔄 Semantica is building: Processing relationships... 4338/4822 🧠 kg GraphBuilder |█████████████░░| 90.0% ETA: 0.0s Rate: 185573.2/s Time: 0.02s Extracted: -🔄 Semantica is building ...
# [DONE] Graph structure built (0.00s)
# 🔄 Semantica is resolving: Checking fields for conflicts... 0/2 (remaining: 2) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 0/697 (remaining: 697) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 1/697 (remaining: 696) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.1% ETA: 0.7s Rate: 1006.6/s Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 6/697 (remaining: 691) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 0.9% ETA: 0.2s Rate: 2932.4/s Time: 0.00s Extracted: -🔄 Semantica is resolving: Analyzing entities... 12/697 (remaining: 685) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 1.7% ETA: 0.3s Rate: 2065.7/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 18/697 (remaining: 679) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 2.6% ETA: 0.2s Rate: 2791.7/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 24/697 (remaining: 673) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 3.4% ETA: 0.2s Rate: 3363.2/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 30/697 (remaining: 667) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 4.3% ETA: 0.2s Rate: 3945.4/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 36/697 (remaining: 661) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 5.2% ETA: 0.2s Rate: 4197.6/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 42/697 (remaining: 655) ⚠️ conflicts ConflictDetector |░░░░░░░░░░░░░░░| 6.0% ETA: 0.1s Rate: 4628.9/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 48/697 (remaining: 649) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 6.9% ETA: 0.1s Rate: 4754.3/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 54/697 (remaining: 643) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 7.7% ETA: 0.1s Rate: 4906.8/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 60/697 (remaining: 637) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 8.6% ETA: 0.1s Rate: 5202.7/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 66/697 (remaining: 631) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 9.5% ETA: 0.1s Rate: 4893.4/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 72/697 (remaining: 625) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 10.3% ETA: 0.1s Rate: 4913.1/s Time: 0.01s Extracted: -🔄 Semantica is resolving: Analyzing entities... 78/697 (remaining: 619) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 11.2% ETA: 0.1s Rate: 5177.5/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 84/697 (remaining: 613) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 12.1% ETA: 0.1s Rate: 5220.0/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 90/697 (remaining: 607) ⚠️ conflicts ConflictDetector |█░░░░░░░░░░░░░░| 12.9% ETA: 0.1s Rate: 5345.9/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 96/697 (remaining: 601) ⚠️ conflicts ConflictDetector |██░░░░░░░░░░░░░| 13.8% ETA: 0.1s Rate: 5460.5/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 102/697 (remaining: 595) ⚠️ conflicts ConflictDetector |██░░░░░░░░░░░░░| 14.6% ETA: 0.1s Rate: 5599.3/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 108/697 (remaining: 589) ⚠️ conflicts ConflictDetector |██░░░░░░░░░░░░░| 15.5% ETA: 0.1s Rate: 5599.5/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 114/697 (remaining: 583) ⚠️ conflicts ConflictDetector |██░░░░░░░░░░░░░| 16.4% ETA: 0.1s Rate: 5786.2/s Time: 0.02s Extracted: -🔄 Semantica is resolving: Analyzing entities... 120/697 (remaining: 577) ⚠️ conflicts ConflictDetector |██░░░░░░░░░░░░░| 17.2% ETA: 0.1s Rate: 5936.9/s Time: 0.02s Extracted: -🔄  ...
# ============================================================
# [INFO] Extraction Statistics
#    Extracted Entities: 0
#    Extracted Relationships: 0
#    Extracted Triplets: 0
# ============================================================
#
# ============================================================
# [DONE] Knowledge Graph Build Complete
#    Entities: 697
#    Relationships: 4822
#    Total time: 0.69s
# ============================================================
# Knowledge graph build completed (no additional merging)
# Final entities: 697
# Final relationships: 4822

# %% [markdown]
# ## Step 10: Analyze Knowledge Graph
#
# This step evaluates the structure and quality of the knowledge graph.
#
# - **Centrality**
#   Identifies the most influential entities based on connectivity.
#
# - **Communities**
#   Groups related entities to reveal themes such as business units, markets, or topics.
#
# - **Connectivity**
#   Shows how well the graph is linked and whether information is fragmented.
#
# These metrics help validate extraction quality and guide downstream analysis.

# %%
from semantica.kg import GraphAnalyzer

graph_analyzer = GraphAnalyzer()

analysis = graph_analyzer.analyze_graph(knowledge_graph)
centrality = graph_analyzer.calculate_centrality(
    knowledge_graph,
    method="degree",
)
communities = graph_analyzer.detect_communities(
    knowledge_graph,
    algorithm="louvain",
)
connectivity = graph_analyzer.analyze_connectivity(knowledge_graph)
metrics = graph_analyzer.compute_metrics(knowledge_graph)

num_communities = len(communities.get("communities", []))

print("Graph analysis completed")
print("Communities:", num_communities)
# Out:
# 🔄 Semantica is building: Calculating degree centrality 🧠 kg CentralityCalculator |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -✅ Semantica is building: Detected 15 communities 🧠 kg CommunityDetector |███████████████| 100.0% ETA: - Rate: - Time: 0.05s Extracted: -Graph analysis completed
# Communities: 15

# %% [markdown]
# ## Step 11: Persist Knowledge Graph in Amazon Neptune
#
# After cleaning, conflict resolution, and deduplication, the final step is to
# persist the **canonical knowledge graph** into a production graph database.
#
# Semantica integrates with **Amazon Neptune** to provide a secure, scalable,
# and query-efficient backend for long-lived knowledge graphs.
#
# - **Canonical Storage**
#   Only deduplicated entities and resolved relationships are written to Neptune.
#
# - **Secure Access**
#   Uses AWS IAM authentication (SigV4) for production-grade security.
#
# - **Flexible Graph Model**
#   Supports property graphs (OpenCypher / Gremlin) and RDF (SPARQL).
#
# - **Efficient Querying**
#   Leverages the Bolt protocol for low-latency graph queries and traversal.
#
# - **Production Ready**
#   Designed for compliance, provenance, and downstream analytics.
#
# This step enables durable storage, rich querying, and integration with
# analytics and applications on top of the extracted knowledge graph.

# %%
import os

os.environ["NEPTUNE_ENDPOINT"] = "your-cluster.us-east-1.neptune.amazonaws.com"
os.environ["NEPTUNE_PORT"] = "8182"
os.environ["AWS_REGION"] = "us-east-1"

# %%
from semantica.graph_store import GraphStore
import os

neptune_store = GraphStore(
    backend="neptune",
    endpoint=os.environ["NEPTUNE_ENDPOINT"],
    port=int(os.environ.get("NEPTUNE_PORT", 8182)),
    region=os.environ["AWS_REGION"],
    iam_auth=True,
)

neptune_store.connect()
print("Connected to AWS Neptune")

# %%
for entity in knowledge_graph.get("entities", []):
    neptune_store.create_node(
        labels=[entity.get("type", "Entity")],
        properties=entity,
    )

for rel in knowledge_graph.get("relationships", []):
    neptune_store.create_relationship(
        start_node_id=rel["source"],
        end_node_id=rel["target"],
        rel_type=rel["predicate"],
        properties=rel.get("metadata", {}),
    )

print("Knowledge graph populated to AWS Neptune")

# %%
# Verify data in Neptune
results = neptune_store.execute_query(
    "MATCH (n) RETURN count(n) AS node_count"
)
print("Total nodes:", results.get("records", [{}])[0].get("node_count"))

results = neptune_store.execute_query(
    "MATCH ()-[r]->() RETURN count(r) AS rel_count"
)
print("Total relationships:", results.get("records", [{}])[0].get("rel_count"))

# Sample query: list a few entities
results = neptune_store.execute_query(
    "MATCH (n) RETURN labels(n), n.name LIMIT 5"
)

print("Sample nodes:")
for r in results.get("records", []):
    print(r)

# %% [markdown]
# ## Step 12: Context Retrieval
#
# Set up hybrid retrieval (vector + graph) using ContextRetriever for GraphRAG queries.

# %%
import time
from semantica.vector_store import VectorStore
from semantica.context import ContextRetriever

if 'chunks' not in locals() or not chunks:
    raise ValueError("Chunks not found. Please run Step 3 first.")

# Extract text content safely
chunk_texts = [getattr(c, "content", getattr(c, "text", "")) for c in chunks]
chunk_metadatas = [
    {
        "source": "earnings_call",
        "type": "transcript",
        "chunk_index": i,
        **(getattr(c, "metadata", {}) or {})
    }
    for i, c in enumerate(chunks)
]

# Initialize Vector Store (Optimized for Speed)
# dimension=384 matches the default fast model (BAAI/bge-small-en-v1.5)
vector_store = VectorStore(
    backend="faiss",
    dimension=384,
    max_workers=16
)

print(f"Storing {len(chunks)} chunks with high-performance settings...")
start_time = time.time()

# Store in large batches with parallel processing
vector_ids = vector_store.add_documents(
    documents=chunk_texts,
    metadata=chunk_metadatas,
    batch_size=128,
    parallel=True
)

print(f"✅ Stored in {time.time() - start_time:.2f}s")

# Initialize Hybrid Retriever
context_retriever = ContextRetriever(
    knowledge_graph=knowledge_graph, # Assumes knowledge_graph exists
    vector_store=vector_store,
    hybrid_alpha=0.6,
    use_graph_expansion=True,
    max_expansion_hops=2,
)

# Test Retrieval
queries = [
    "What was the company's revenue guidance?",
    "What were the key financial metrics discussed?",
]

retrieved_contexts = []
for query in queries:
    results = context_retriever.retrieve(
        query=query,
        max_results=3,
        min_relevance_score=0.2,
    )
    retrieved_contexts.append(results)

print("Hybrid GraphRAG configured")
print("Sample results:", len(retrieved_contexts[0]) if retrieved_contexts else 0)
# Out:
# Storing 148 chunks with high-performance settings...
# 🔄 Semantica is indexing: Processing 148 documents (parallel=True) 📊 vector_store VectorStore |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -🔄 Semantica is indexing: Storing vectors... 📊 vector_store VectorStore |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 58.47s Extracted: -✅ Stored in 58.47s
# ✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.02s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Gener ...
# WARNING:semantica.vector_store:Embedding generation failed: Text cannot be empty or whitespace-only
# WARNING:semantica.vector_store:Using random fallback embedding
# ✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Gener ...
# WARNING:semantica.vector_store:Embedding generation failed: Text cannot be empty or whitespace-only
# WARNING:semantica.vector_store:Using random fallback embedding
# Hybrid GraphRAG configured
# Sample results: 3

# %% [markdown]
# ## Step 13: Agent Memory (Long-Term Context)
#
# This step enables long-term memory for agents by storing important facts,
# metrics, and entities extracted from the knowledge graph.
#
# - **Semantic Memory Storage**
#   Stores structured memories enriched with entities and relationships,
#   not just raw text.
#
# - **Hybrid Recall**
#   Combines vector similarity with graph structure for accurate retrieval.
#
# - **Time-Bound Retention**
#   Supports memory expiration policies for freshness and governance.
#
# - **Agent-Ready Context**
#   Allows agents to recall prior earnings, metrics, and entities across sessions.
#
# Agent Memory turns one-off analysis into **persistent, reusable intelligence**
# for downstream agents and workflows.

# %%
from semantica.context import AgentMemory

agent_memory = AgentMemory(
    vector_store=vector_store,
    knowledge_graph=knowledge_graph,
    retention_days=30,
)

entity_count = len(knowledge_graph.get("entities", []))
relationship_count = len(knowledge_graph.get("relationships", []))

memory_contents = [
    f"Earnings call transcript: {parsed_doc['metadata'].get('title', 'Earnings Call')}",
    f"Graph entities: {entity_count}",
    f"Graph relationships: {relationship_count}",
]

memory_ids = []

for content in memory_contents:
    memory_ids.append(
        agent_memory.store(
            content=content,
            metadata={"source": "earnings_call", "type": "analysis"},
            extract_entities=True,
            extract_relationships=True,
        )
    )

financial_memories = agent_memory.retrieve(
    query="financial metrics and earnings",
    max_results=5,
)

memory_stats = agent_memory.get_statistics()

print("Agent memory configured")
print("Memories stored:", len(memory_ids))
print("Total memories:", memory_stats.get("total_memories", 0))
print("Retrieved memories:", len(financial_memories))
# Out:
# 🔄 Semantica is processing: Storing memory: Earnings call transcript: MDA Space Ltd. Q3 2025 E... 🔗 context AgentMemory |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -Agent memory configured
# Memories stored: 3
# Total memories: 0
# Retrieved memories: 1

# %% [markdown]
# ## Step 14: Agent Context
#
# **AgentContext** provides a unified context layer that combines **vector-based RAG**
# with **graph-based GraphRAG** for grounded and explainable retrieval.
#
# ### Key Controls
# - **Graph Expansion**
#   Uses connected entities and relationships from the knowledge graph to
#   expand context beyond direct text matches.
#
# - **Hybrid Alpha**
#   Balances text similarity with graph structure. Lower values favor text;
#   higher values favor graph reasoning.
#
# - **Expansion Hops**
#   Limits how far context can expand through the graph. Fewer hops keep
#   results focused; more hops increase coverage.
#
# AgentContext enables agents to reason over both **documents** and
# **knowledge graphs** through a single interface.
#
#
# ### AgentContext Parameters
#
# - **vector_store** – Vector search over unstructured text
# - **knowledge_graph** – Structured entities and relationships
# - **use_graph_expansion** – Enable GraphRAG (graph-based context expansion)
# - **max_expansion_hops** – How far to traverse the graph
# - **hybrid_alpha** – Balance between vector and graph relevance
# - **retention_days** – How long context is kept
#
# **Store options**
# - **link_entities** – Link to existing graph nodes
#
# **Retrieve options**
# - **max_results** – Number of results returned
# - **expand_graph** – Expand context via the graph
# - **include_entities** – Return related entities
#
# AgentContext unifies **memory, GraphRAG, and retrieval** in one interface.

# %%
from semantica.context import AgentContext

agent_context = AgentContext(
    vector_store=vector_store,
    knowledge_graph=knowledge_graph,
    use_graph_expansion=True,
    max_expansion_hops=2,
    hybrid_alpha=0.6,
    retention_days=30,
)

memory_id = agent_context.store(
    content=parsed_doc["full_text"][:],
    metadata={"source": "earnings_call", "date": "2024-Q1"},
    extract_entities=True,
    extract_relationships=True,
    link_entities=True,
)

results = agent_context.retrieve(
    query="What was discussed about revenue growth?",
    max_results=5,
    expand_graph=True,
    include_entities=True,
)

stats = agent_context.stats()

print("AgentContext configured")
print("Memory stored:", memory_id)
print("GraphRAG results:", len(results))
print("Total memories:", stats.get("total_memories", 0))
# Out:
# 🔄 Semantica is processing: Storing memory: # Press Release
#
# ## NEWS RELEASE
#
# ## MDA SPACE REP... 🔗 context AgentMemory |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.81s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.02s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings Text ...
# WARNING:semantica.vector_store:Embedding generation failed: Text cannot be empty or whitespace-only
# WARNING:semantica.vector_store:Using random fallback embedding
# ✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.07s Extracted: -AgentContext configured
# Memory stored: mem_74cfce72a1b1
# GraphRAG results: 5
# Total memories: 0

# %% [markdown]
# ## Step 15: Answer Generation
#
# Generate answers to financial questions using Groq LLM with retrieved context and knowledge graph.

# %%
financial_questions = [
    "What were the key financial metrics discussed?",
    "What guidance was provided for future quarters?",
]

generated_answers = []

print("--- Generating Enhanced Answers ---\n")

def format_context(retrieved_contexts):
    """Formats retrieved context with graph information."""
    formatted_parts = []

    for i, ctx in enumerate(retrieved_contexts):
        content = getattr(ctx, "content", "")
        source = getattr(ctx, "source", "unknown")

        # Format related entities from the graph
        related_entities = getattr(ctx, "related_entities", [])
        entities_str = ", ".join([
            f"{e.get('name', 'Unknown')} ({e.get('type', 'Entity')})"
            for e in related_entities[:5]  # Limit to top 5 per chunk
        ])

        # Format related relationships
        related_rels = getattr(ctx, "related_relationships", [])
        rels_str = "; ".join([
            f"{r.get('source', '')} -> {r.get('type', '')} -> {r.get('target', '')}"
            for r in related_rels[:3]  # Limit to top 3 per chunk
        ])

        part = f"Source {i+1} ({source}):\n{content}\n"
        if entities_str:
            part += f"Related Entities: {entities_str}\n"
        if rels_str:
            part += f"Graph Connections: {rels_str}\n"

        formatted_parts.append(part)

    return "\n---\n".join(formatted_parts)

for question in financial_questions:
    print(f"Question: {question}")

    # Retrieve with graph expansion enabled and higher limits
    retrieved_contexts = context_retriever.retrieve(
        query=question,
        max_results=10,          # Increased from 3
        min_relevance_score=0.2,
        use_graph_expansion=True, # Explicitly enable graph expansion
        max_hops=2               # Traverse up to 2 hops in the graph
    )

    # Use the rich formatter
    context_text = format_context(retrieved_contexts)

    # Get global key entities (optional, but good for high-level context)
    global_entities = [
        f"{e.get('name', '')} ({e.get('type', '')})"
        for e in knowledge_graph.get("entities", [])[:10]
    ]
    global_entities_text = ", ".join(global_entities)

    prompt = f"""
Answer the question comprehensively using the provided context.
The context includes text chunks and knowledge graph connections (entities and relationships).
If the answer is not present, say so.

Context:
{context_text}

Global Key Entities: {global_entities_text}

Question:
{question}

Answer:
""".strip()

    try:
        answer = groq_llm.generate(
            prompt,
            temperature=0.3, # Lower temperature for more factual answers
            max_tokens=1000, # Allow longer answers
        )
    except Exception as error:
        answer = f"Answer generation failed: {error}"

    generated_answers.append(answer)
    print(f"Answer: {answer}\n")
    print("-" * 50 + "\n")

print("Answer generation completed")
print("Questions answered:", len(generated_answers))
# Out:
# --- Generating Enhanced Answers ---
#
# Question: What were the key financial metrics discussed?
# 🔄 Semantica is processing: Retrieving context for: What were the key financial metrics discussed?... 🔗 context ContextRetriever |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.04s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s  ...
# WARNING:semantica.vector_store:Embedding generation failed: Text cannot be empty or whitespace-only
# WARNING:semantica.vector_store:Using random fallback embedding
# Answer: Based on the provided context, the key financial metrics discussed include:
#
# 1. Finance income (EVENT)
# 2. Finance costs (EVENT, MONEY, ORGANIZATION)
# 3. Net capital expenditures (MONEY)
# 4. Acquisition, integration and reorganization costs (EVENT)
# 5. Unrealized loss (gain) on financial instruments (EVENT)
# 6. $4.4 billion (MONEY)
# 7. $409.8 million (MONEY)
# 8. $82.8 million (MONEY)
# 9. $46.1 million (MONEY)
# 10. $0.35 (MONEY)
# 11. $32.8 million (MONEY)
#
# These financial metrics provide a comprehensive overview of the financial performance and activities of the organization, MDA Space Ltd.
#
# --------------------------------------------------
#
# Question: What guidance was provided for future quarters?
# 🔄 Semantica is processing: Retrieving context for: What guidance was provided for future quarters?... 🔗 context ContextRetriever |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s Extracted: -✅ Semantica is embedding: Generated embedding (dim: 384) 💾 embeddings TextEmbedder |███████████████| 100.0% ETA: - Rate: - Time: 0.01s ...
# WARNING:semantica.vector_store:Embedding generation failed: Text cannot be empty or whitespace-only
# WARNING:semantica.vector_store:Using random fallback embedding
# Answer: Based on the provided context, there is no information about guidance provided for future quarters. The context includes information about various dates, events, and financial data, but it does not mention any guidance for future quarters.
#
# --------------------------------------------------
#
# Answer generation completed
# Questions answered: 2

# %% [markdown]
# ## Step 16: Export Results
#
# Export knowledge graph and analysis results to JSON and RDF formats.

# %%
from semantica.export import JSONExporter, RDFExporter
import json

# Initialize exporters
json_exporter = JSONExporter()
rdf_exporter = RDFExporter()

# Define output file paths
json_output_path = "knowledge_graph.json"
rdf_output_path = "knowledge_graph.ttl"

# Export to files (required by the API)
json_exporter.export(knowledge_graph, file_path=json_output_path, format="json")

# FIXED: Use .export() instead of .export_to_rdf() to write to disk
rdf_exporter.export(knowledge_graph, file_path=rdf_output_path, format="turtle")

# Load the RDF file content to check its size
with open(rdf_output_path, "r", encoding="utf-8") as f:
    kg_rdf_content = f.read()

# Create analysis summary
analysis_summary = {
    "entities": len(knowledge_graph.get("entities", [])),
    "relationships": len(knowledge_graph.get("relationships", [])),
    "entity_conflicts_resolved": len(locals().get("resolved_entity_value_conflicts", [])),
    "relationship_conflicts_resolved": len(locals().get("resolved_relationship_conflicts", [])),
    "deduplicated_entities": len(locals().get("deduplicated_entities", [])),
    "communities": locals().get("num_communities", 0),
    "questions_answered": len(generated_answers),
    "llm_model": getattr(groq_llm, "model", "unknown"),
}

print("Export completed")
print("KG JSON entities:", analysis_summary["entities"])
print("KG RDF size (chars):", len(kg_rdf_content))
print("Questions answered:", analysis_summary["questions_answered"])
print("LLM model:", analysis_summary["llm_model"])
print("Conflicts resolved:", analysis_summary["entity_conflicts_resolved"] + analysis_summary["relationship_conflicts_resolved"])
# Out:
# 🔄 Semantica is exporting: Exporting data to JSON: knowledge_graph.json 💾 export JSONExporter |░░░░░░░░░░░░░░░| 0.0% ETA: - Rate: - Time: 0.00s Extracted: -Export completed
# KG JSON entities: 697
# KG RDF size (chars): 244718
# Questions answered: 2
# LLM model: llama-3.1-8b-instant
# Conflicts resolved: 58
