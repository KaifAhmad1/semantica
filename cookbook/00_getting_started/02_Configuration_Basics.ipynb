# %% [markdown]
# # Configuration Basics
#
# ## Overview
#
# Learn how to configure Semantica using ConfigManager, environment variables, and config files.
#
# ## ConfigManager Basics
#
# '''
# # from semantica.core import ConfigManager
# #
# # config = ConfigManager()
# #
# # # Access configuration values
# # api_key = config.get("api_key")
# # model_name = config.get("model_name", default="default-model")
# '''
#
# ## Environment Variables
#
# '''
# # Set environment variables:
# # export SEMANTICA_API_KEY=your_key
# # export SEMANTICA_MODEL_NAME=your_model
# #
# # Access in code:
# # import os
# # api_key = os.getenv("SEMANTICA_API_KEY")
# '''
#
# ## Config Files (YAML/JSON)
#
# '''
# # Create a config.yaml file:
# # api_key: your_api_key
# # model_name: your_model
# # embedding_provider: openai
# #
# # Load configuration:
# # config = ConfigManager.from_file("config.yaml")
# #
# # Or use JSON:
# # config = ConfigManager.from_file("config.json")
# '''
#
# ## Common Settings
#
# '''
# # Common configuration settings:
# # - API keys for various providers
# # - Model names and parameters
# # - Embedding dimensions
# # - Graph database connections
# # - Logging levels
# # - Cache settings
# '''
